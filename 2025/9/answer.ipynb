# %% [markdown]
# # Advent of Code 2025, Day 9

# %%
with open('input.txt', 'r') as f:
    puzzle_input = f.read().strip()

# %% [markdown]
# ## [First Puzzle:](https://adventofcode.com/2025/day/9)

# %% [markdown]
# ## [Second Puzzle:](https://adventofcode.com/2025/day/9/#part2)
